# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_iris
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram

# %%
iris = load_iris()

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
df['sepal length (cm)'] = (df['sepal length (cm)'] - df['sepal length (cm)'].mean()) 
df['sepal length (cm)'].std()
# Out:
# 0.8280661279778629

# %%
df['petal length (cm)'] = (df['petal length (cm)'] - df['petal length (cm)'].mean()) 
df['petal length (cm)'].std()
# Out:
# 1.7652982332594664

# %%
Z = linkage(df[['sepal length (cm)', 'petal length (cm)']], 'ward')

# %%
labels = fcluster(Z, 3, criterion='maxclust')

# %%
df['cluster'] = labels

# %%
plt.figure(figsize=(25, 10))
dendrogram(Z)
plt.title("Iris Dendrogram")
plt.xlabel("Sample Index")
plt.ylabel("Distance")
# Out:
# Text(0, 0.5, 'Distance')

# %%
sns.scatterplot(x=df['sepal length (cm)'], y=df['petal length (cm)'], hue=df['cluster'],
palette='Dark2')
plt.title("Iris Clustered Data")
plt.xlabel("Standardized Sepal Length (cm)")
plt.ylabel("Standardized Petal Length (cm)")
plt.show()

# %% [markdown]
# With using dataset

# %%
iris = pd.read_csv("iris.csv")
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris['sepal.width'] = (iris['sepal.width'] - iris['sepal.width'].mean()) 
iris['sepal.width'].std()
iris['petal.length'] = (iris['petal.length'] - iris['petal.length'].mean()) 
iris['petal.length'].std()
# Out:
# 1.7652982332594664

# %%
Z = linkage(iris[['sepal.length', 'petal.length']], 'ward')

# %%
labels = fcluster(Z, 3, criterion='maxclust')

# %%
iris['cluster'] = labels

# %%
plt.figure(figsize=(25, 10))
dendrogram(Z)
plt.title("Iris Dendrogram")
plt.xlabel("Sample Index")
plt.ylabel("Distance")
# Out:
# Text(0, 0.5, 'Distance')

# %%
sns.scatterplot(x=iris['sepal.length'], y=iris['petal.length'], hue=iris['cluster'],
palette='Dark2')
plt.title("Iris Clustered Data")
plt.xlabel("Standardized Sepal Length (cm)")
plt.ylabel("Standardized Petal Length (cm)")
plt.show()
